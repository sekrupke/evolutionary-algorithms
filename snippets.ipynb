# %% [markdown]
# Example for approximation of expected vector "norm" value for 5-dimensional gaussion distribution N(0, 1).

# %%
import numpy as np

_sum = 0

for i in range(1000):
    norm = np.linalg.norm(np.random.randn(100))
    _sum = _sum + norm

expectedValue = _sum / 1000

print (expectedValue)
# Out:
# 9.996407748869203

# %%
np.sqrt(100 - 1/2)
# Out:
# 9.974968671630002
